# %%
def login_notjson():
    #json으로 cookie를 cookie.json 저장하기
    #한번은 실행하여 json 저장해야함
    path = "C:\python_temp\chromedriver_win32_93.0\chromedriver.exe"
    driver = webdriver.Chrome(path)
    driver.get("https://www.instagram.com/accounts/login/")
    time.sleep(2)

#     username='_timeproject2_'
#     password= 'projectteam2'
    username='iseongjin682'
    password= 'osj4216!'
    driver.find_element_by_xpath('//*[@id="loginForm"]/div/div[1]/div/label/input').send_keys(username)
    driver.find_element_by_xpath('//*[@id="loginForm"]/div/div[2]/div/label/input').send_keys(password)
    driver.find_element_by_xpath('//*[@id="loginForm"]/div/div[3]/button/div').click()
    time.sleep(2)
    try:
        driver.find_element_by_xpath('//*[@id="react-root"]/section/main/div/div/div/div/button').click()
    except:
        pass
    time.sleep(2)
    try:
        driver.find_element_by_xpath('/html/body/div[5]/div/div/div/div[3]/button[2]').click()
    except:
        pass
    time.sleep(2)
    #json으로 현 쿠키값 저장하기
    with open('cookies.json','w') as cookie_json_w:
        json.dump(driver.get_cookies(),cookie_json_w)

# %%
login_notjson()

# %%
# #사용함수
from selenium import webdriver
from bs4 import BeautifulSoup, NavigableString
import requests
import time
import pandas as pd
import json
from selenium.webdriver.common.keys import Keys
import re
import emoji

#미사용
# import pickle
# import os
# import urllib

user2=[]
img2=[]
post2=[]
hasht2=[]
hasht3=[]
like2=[]
day2=[]


path = "C:\python_temp\chromedriver_win32_93.0\chromedriver.exe"
driver = webdriver.Chrome(path)
driver.get("https://www.instagram.com/accounts/login/")
time.sleep(2)
#전체화면
driver.maximize_window()
time.sleep(1)
#pickle로 cookie 불러오기
cookies=json.load(open('cookies.json','r'))
for cookie in cookies:
    driver.add_cookie(cookie)
time.sleep(1)
driver.refresh() #새로고침
time.sleep(2)
try:
    driver.find_element_by_xpath('/html/body/div[5]/div/div/div/div[3]/button[2]').click()
    time.sleep(2)
except:
    pass


search=input('검색할 내용을 입력하세요 : ')
elements=driver.find_element_by_class_name('XTCLo')
elements.send_keys(search)
time.sleep(1)
elements.send_keys(Keys.ARROW_DOWN)
time.sleep(1)
elements.send_keys(Keys.ENTER)
time.sleep(5)
try: 
    driver.find_element_by_xpath('/html/body/div[6]/div[3]/button').click()
except:
    pass
    
driver.find_element_by_xpath('//*[@id="react-root"]/section/main/article/div[2]/div/div[1]/div[1]/a/div[1]/div[2]').click()
time.sleep(1)
cnt=1
while cnt<10:
    page=driver.page_source
    soup=BeautifulSoup(page,'html.parser')
    try:
        user=soup.find('article','M9sTE').find('div','e1e1d').find('a').get_text()
    except AttributeError:
        user=''
    user2.append(user)
    
    try:
        img_src=soup.find('article','M9sTE').find('img')
    except AttributeError:
        img=''
    img=img_src['src']
    img2.append(img)
    print(img2)

    hasht2=[]
    try:
        hashts=soup.find('article','M9sTE').find_all('a','xil3i')
    except AttributeError:
        hasht=''
    for i in hashts:
        hasht=i.get_text()
        hasht2.append(hasht)
#         ','.join(hasht2)
    hasht3.append(hasht2)
#     hasht2=[]
    
    posts=soup.find('article','M9sTE').find('div','X7jCj').find('div','C4VMK').find_all('span')[1]
    try:
        for tag in posts.find_all('a'):
            tag.extract()
        post=posts.get_text()
    except AttributeError:
        post=''
    post2.append(post)
        
    likes=soup.find('article','M9sTE')
    try:
        like=likes.find('a','zV_Nj').get_text()
    except AttributeError:
        like=''
    like2.append(like)

    day=soup.find('article','M9sTE').find('time','_1o9PC').get_text()
    day2.append(day)

    driver.find_element_by_class_name('_65Bje').click()
    time.sleep(1)
    print(cnt)
    cnt+=1
    

save=pd.DataFrame({'아이디':user2,'이미지':img2,'게시글':post2,'해시태그':hasht3,'좋아요':like2,'게시시간':day2})
save.to_csv('insta{}.csv'.format(time.time()),encoding=('utf-8-sig'))

# save=pd.DataFrame({'아이디':user2,'이미지':img2,'게시글':post2,'해시태그':hasht3,'좋아요':like2,'게시시간':day2})
# save.to_excel('insta.xls',encoding=('UTF-8'))
# Out:
# ['blob:https://www.instagram.com/0c8637c4-6e50-43af-babb-2bd43d445cdd']
# 1
# ['blob:https://www.instagram.com/0c8637c4-6e50-43af-babb-2bd43d445cdd', 'https://scontent-ssn1-1.cdninstagram.com/v/t50.16885-16/10000000_997515697477615_8926051020537046197_n.mp4?_nc_ht=scontent-ssn1-1.cdninstagram.com&_nc_cat=107&_nc_ohc=6lNp0qv4VjwAX-w0wzN&edm=AP_V10EBAAAA&ccb=7-4&oe=616A4847&oh=ac55fb1a190fc6a96ee65251cacc7572&_nc_sid=4f375e']
# 2
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-6-174bf4b43527> in <module>
#      70     user2.append(user)
#      71
# ---> 72     if driver.find_element_by_class_name('tWeCl') == True:
#      73         try:
#      74             img_src=soup.find('article','M9sTE').find('img')
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     562             element = driver.find_element_by_class_name('foo')
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#     566     def find_elements_by_class_name(self, name):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".tWeCl"}
#   (Session info: chrome=94.0.4606.81)
